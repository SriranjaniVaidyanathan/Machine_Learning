# %% [markdown]
# # Assignment #1 - Linear Regression
#
# ASSIGNMENT DONE BY ,
#
# Name: SRIRANJANI VAIDYANATHAN
#
# Student ID: 801077329
#
# ## INTRODUCTION
#
# This assignment is about the Linear Regression. We use the linear regression model to predict the dependent variable using the independent variable. There are two ways we can predict the dependent value.
#
# 1.	Univariate
# 2.	Bi Variate
# 3.	Multi Variate
#
# Univariate analysis is the simplest form of data analysis where the data being analyzed contains only one variable. Since it's a single variable it doesn’t deal with causes or relationships.  The main purpose of univariate analysis is to describe the data and find patterns that exist within it.
#
# Bivariate analysis is used to find out if there is a relationship between two different variables. Something as simple as creating a scatterplot by plotting one variable against another on a Cartesian plane. If the data seems to fit a line or curve then there is a relationship or correlation between the two variables.
#
# Multivariate analysis is the analysis of three or more variables.  There are many ways to perform multivariate analysis depending on your goals.
#
# There are two statistical techniques used to predict the values.
#
# 1.	Least Square.
# 2.	Least Mean Square.
#
# Least square statistical technique for finding the best-fitting curve to a given set of points by minimizing the sum of the squares of the offsets ("the residuals") of the points from the curve.
# Least squares means that the overall solution minimizes the sum of the squares of the residuals made in the results of every single equation.
#
# The data source from which the data was collected is Kaggle("https://www.kaggle.com/datasets"). The data set used for regression contains data that describes daily weather observations from numerous Australian weather stations.

# %% [markdown]
# # DATA
#
# ## INTRODUCTION OF DATA FOR REGRESSION AND SOURCE
#
# The Data used for regression describes daily weather observations from numerous Australian weather stations. This data set contains 142,000 samples and 24 feature values.
#
# The information about the columns is described below,
#
# Date                - It is the date of observation.
#
# Location            - The common name of the location of the weather station
#
# MinTemp             - The minimum temperature in degrees celsius
#
# MaxTemp             - The maximum temperature in degrees celsius
#
# Rainfall            - The amount of rainfall recorded for the day in mm
#
# Evaporation         - The so-called Class A pan evaporation (mm) in the 24 hours to 9am
#
# Sunshine            - The number of hours of bright sunshine in the day.
#
# WindGustDir         - The direction of the strongest wind gust in the 24 hours to midnight
#
# WindGustSpeed       - The speed (km/h) of the strongest wind gust in the 24 hours to midnight
#
# WindDir9am          - Direction of the wind at 9am
#
# WindDir3pm          - Direction of the wind at 3pm
#
# WindSpeed9am        - Wind speed (km/hr) averaged over 10 minutes prior to 9am
#
# WindSpeed3pm        - Wind speed (km/hr) averaged over 10 minutes prior to 3pm
#
# Humidity9am         - Humidity (percent) at 9am
#
# Humidity3pm         - Humidity (percent) at 3pm
#
# Pressure9am         - Atmospheric pressure (hpa) reduced to mean sea level at 9am
#
# Pressure3pm         - Atmospheric pressure (hpa) reduced to mean sea level at 3pm
#
# Cloud9am            - Fraction of sky obscured by cloud at 9am. This is measured in "oktas", which are a unit of eigths. It records how many eigths of the sky are obscured by cloud. A 0 measure indicates completely clear sky whilst an 8 indicates that it is completely overcast.
#
# Cloud3pm            - Fraction of sky obscured by cloud (in "oktas": eighths) at 3pm. See Cload9am for a description of the values
#
# Temp9am             - Temperature (degrees C) at 9am
#
# Temp3pm             - Temperature (degrees C) at 3pm
#
# RainToday           - Boolean: 1 if precipitation (mm) in the 24 hours to 9am exceeds 1mm, otherwise 0
#
# RISK_MM             - The amount of rain. A kind of measure of the "risk".
#
# RainTomorrow        - The target variable. Did it rain tomorrow?

# %% [markdown]
# ## READING THE DATA

# %% [markdown]
# Before we start reading the format we have to import the necessary packages.

# %%
#Import Statements.

import numpy as np
from abc import ABC, abstractmethod
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.pyplot import pie, axis, show
import datetime
import seaborn as sns
from sklearn.model_selection import train_test_split
import IPython.display as ipd 
# %matplotlib inline

# %% [markdown]
# We will be creating a data frame that will store the data read from the csv file.
#
# Data Frame is a data structure representing cases (rows), each of which consists of a number of observations or measurements (columns).

# %%
#The dataset is in CSV format. 
df = pd.read_csv("weatherAUS.csv")
df
# Out:
#               Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 0       2008-12-01   Albury     13.4     22.9       0.6          NaN
# 1       2008-12-02   Albury      7.4     25.1       0.0          NaN
# 2       2008-12-03   Albury     12.9     25.7       0.0          NaN
# 3       2008-12-04   Albury      9.2     28.0       0.0          NaN
# 4       2008-12-05   Albury     17.5     32.3       1.0          NaN
# 5       2008-12-06   Albury     14.6     29.7       0.2          NaN
# 6       2008-12-07   Albury     14.3     25.0       0.0          NaN
# 7       2008-12-08   Albury      7.7     26.7       0.0          NaN
# 8       2008-12-09   Albury      9.7     31.9       0.0          NaN
# 9       2008-12-10   Albury     13.1     30.1       1.4          NaN
# 10      2008-12-11   Albury     13.4     30.4       0.0          NaN
# 11      2008-12-12   Albury     15.9     21.7       2.2          NaN
# 12      2008-12-13   Albury     15.9     18.6      15.6          NaN
# ...

# %% [markdown]
# Inorder to know about the data set we can use describe() which will describe about all the feature values in the data frame df.

# %%
#Generate descriptive statistics that summarize the central tendency, dispersion and shape of a dataset’s distribution, excluding NaN values

df.describe()
# Out:
#              MinTemp        MaxTemp       Rainfall   Evaporation  \
# count  141556.000000  141871.000000  140787.000000  81350.000000
# mean       12.186400      23.226784       2.349974      5.469824
# std         6.403283       7.117618       8.465173      4.188537
# min        -8.500000      -4.800000       0.000000      0.000000
# 25%         7.600000      17.900000       0.000000      2.600000
# 50%        12.000000      22.600000       0.000000      4.800000
# 75%        16.800000      28.200000       0.800000      7.400000
# max        33.900000      48.100000     371.000000    145.000000
#
#            Sunshine  WindGustSpeed   WindSpeed9am   WindSpeed3pm  \
# count  74377.000000  132923.000000  140845.000000  139563.000000
# mean       7.624853      39.984292      14.001988      18.637576
# std        3.781525      13.588801       8.893337       8.803345
# min        0.000000       6.000000       0.000000       0.000000
# ...

# %% [markdown]
# In order to know more information about the data set we use info() which will provide information about the type, total number of non null values for all the feature values in the data frame.

# %%
#Print a concise summary of a DataFrame.

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 142193 entries, 0 to 142192
# Data columns (total 24 columns):
# Date             142193 non-null object
# Location         142193 non-null object
# MinTemp          141556 non-null float64
# MaxTemp          141871 non-null float64
# Rainfall         140787 non-null float64
# Evaporation      81350 non-null float64
# Sunshine         74377 non-null float64
# WindGustDir      132863 non-null object
# WindGustSpeed    132923 non-null float64
# WindDir9am       132180 non-null object
# WindDir3pm       138415 non-null object
# WindSpeed9am     140845 non-null float64
# WindSpeed3pm     139563 non-null float64
# Humidity9am      140419 non-null float64
# Humidity3pm      138583 non-null float64
# Pressure9am      128179 non-null float64
# Pressure3pm      128212 non-null float64
# Cloud9am         88536 non-null float64
# Cloud3pm         85099 non-null float64
# Temp9am          141289 non-null float64
# ...

# %% [markdown]
# ## PREPROCESSING OF THE DATA

# %% [markdown]
# So before we start with the visualization we need to preprocess the data so that the data does not have any null values or not a number values. The string values should be converted to numeric values as well.Also we can remove the columns which are not needed.

# %% [markdown]
# Everytime it is safe to create a duplicate for the data frame and make changes in the new data frame. So here I have created a new data frame X which has all the data from the data frame df and the preprocessing is done in the data frame X.

# %%
#Copy the data from the dataframe df to another dataframe X.
X = df.iloc[:, :].copy()

#Chages are made in the new dataframe X.
#The columns that are not required are dropped.
X = X.drop(columns=['Evaporation', 'Sunshine','Cloud9am', 'Cloud3pm','WindGustDir', 'WindDir9am', 'WindDir3pm', 'RainToday', 'RainTomorrow', 'RISK_MM', 'Location'])
np.any(X.isnull())
X
# Out:
#               Date  MinTemp  MaxTemp  Rainfall  WindGustSpeed  WindSpeed9am  \
# 0       2008-12-01     13.4     22.9       0.6           44.0          20.0
# 1       2008-12-02      7.4     25.1       0.0           44.0           4.0
# 2       2008-12-03     12.9     25.7       0.0           46.0          19.0
# 3       2008-12-04      9.2     28.0       0.0           24.0          11.0
# 4       2008-12-05     17.5     32.3       1.0           41.0           7.0
# 5       2008-12-06     14.6     29.7       0.2           56.0          19.0
# 6       2008-12-07     14.3     25.0       0.0           50.0          20.0
# 7       2008-12-08      7.7     26.7       0.0           35.0           6.0
# 8       2008-12-09      9.7     31.9       0.0           80.0           7.0
# 9       2008-12-10     13.1     30.1       1.4           28.0          15.0
# 10      2008-12-11     13.4     30.4       0.0           30.0          17.0
# ...

# %% [markdown]
# There are total of 142,193 samples and removing the rows with na values will result in 119,590 samples which doesnt affect the output to get biased.

# %% [markdown]
# So removing the rows with the null values using dropna() and displaying the data frame X

# %%
#The rows which has na values is dropped and the index are renumbered. 

X = X.dropna(how='any').reset_index()

#Print the dataframe after preprocessing. 
X
# Out:
#          index        Date  MinTemp  MaxTemp  Rainfall  WindGustSpeed  \
# 0            0  2008-12-01     13.4     22.9       0.6           44.0
# 1            1  2008-12-02      7.4     25.1       0.0           44.0
# 2            2  2008-12-03     12.9     25.7       0.0           46.0
# 3            3  2008-12-04      9.2     28.0       0.0           24.0
# 4            4  2008-12-05     17.5     32.3       1.0           41.0
# 5            5  2008-12-06     14.6     29.7       0.2           56.0
# 6            6  2008-12-07     14.3     25.0       0.0           50.0
# 7            7  2008-12-08      7.7     26.7       0.0           35.0
# 8            8  2008-12-09      9.7     31.9       0.0           80.0
# 9            9  2008-12-10     13.1     30.1       1.4           28.0
# 10          10  2008-12-11     13.4     30.4       0.0           30.0
# 11          11  2008-12-12     15.9     21.7       2.2           31.0
# ...

# %%
X.dtypes
# Out:
# index              int64
# Date              object
# MinTemp          float64
# MaxTemp          float64
# Rainfall         float64
# WindGustSpeed    float64
# WindSpeed9am     float64
# WindSpeed3pm     float64
# Humidity9am      float64
# Humidity3pm      float64
# Pressure9am      float64
# Pressure3pm      float64
# Temp9am          float64
# Temp3pm          float64
# dtype: object

# %% [markdown]
# Also I am splitting the Date feature value as date, day and year into seperate columns

# %%
X['year'] = pd.DatetimeIndex(X['Date']).year
X['month'] = pd.DatetimeIndex(X['Date']).month
X['day'] = pd.DatetimeIndex(X['Date']).day
X.head()
# Out:
#    index        Date  MinTemp  MaxTemp  Rainfall  WindGustSpeed  WindSpeed9am  \
# 0      0  2008-12-01     13.4     22.9       0.6           44.0          20.0
# 1      1  2008-12-02      7.4     25.1       0.0           44.0           4.0
# 2      2  2008-12-03     12.9     25.7       0.0           46.0          19.0
# 3      3  2008-12-04      9.2     28.0       0.0           24.0          11.0
# 4      4  2008-12-05     17.5     32.3       1.0           41.0           7.0
#
#    WindSpeed3pm  Humidity9am  Humidity3pm  Pressure9am  Pressure3pm  Temp9am  \
# 0          24.0         71.0         22.0       1007.7       1007.1     16.9
# 1          22.0         44.0         25.0       1010.6       1007.8     17.2
# 2          26.0         38.0         30.0       1007.6       1008.7     21.0
# 3           9.0         45.0         16.0       1017.6       1012.8     18.1
# 4          20.0         82.0         33.0       1010.8       1006.0     17.8
#
#    Temp3pm  year  month  day
# ...

# %% [markdown]
# Now display X to see your final data frame after preprocessing.

# %%
# Print X
X
# Out:
#          index        Date  MinTemp  MaxTemp  Rainfall  WindGustSpeed  \
# 0            0  2008-12-01     13.4     22.9       0.6           44.0
# 1            1  2008-12-02      7.4     25.1       0.0           44.0
# 2            2  2008-12-03     12.9     25.7       0.0           46.0
# 3            3  2008-12-04      9.2     28.0       0.0           24.0
# 4            4  2008-12-05     17.5     32.3       1.0           41.0
# 5            5  2008-12-06     14.6     29.7       0.2           56.0
# 6            6  2008-12-07     14.3     25.0       0.0           50.0
# 7            7  2008-12-08      7.7     26.7       0.0           35.0
# 8            8  2008-12-09      9.7     31.9       0.0           80.0
# 9            9  2008-12-10     13.1     30.1       1.4           28.0
# 10          10  2008-12-11     13.4     30.4       0.0           30.0
# 11          11  2008-12-12     15.9     21.7       2.2           31.0
# ...

# %% [markdown]
# Now find if there are any null values present in the data frame using np.any(). False if there are no null values and True if there are null values.

# %%
#This statement will check the entire data frame and gives the output in boolean.
#The output is True even if any one of the value in the dataframe is true else false.
np.any(X.isnull())
# Out:
# False

# %% [markdown]
# Once again use describe() to describe the descriptive statistics of the updated dataframe.

# %%
#Descriptive statistics of updated dataframe.

X.describe()
# Out:
#                index        MinTemp        MaxTemp       Rainfall  \
# count  119590.000000  119590.000000  119590.000000  119590.000000
# mean    71466.334418      12.386547      23.485962       2.320947
# std     40218.769959       6.367537       6.986581       8.465116
# min         0.000000      -8.200000       2.600000       0.000000
# 25%     38170.250000       7.700000      18.100000       0.000000
# 50%     72427.500000      12.100000      22.900000       0.000000
# 75%    103177.750000      17.000000      28.500000       0.600000
# max    142192.000000      33.900000      48.100000     367.600000
#
#        WindGustSpeed   WindSpeed9am   WindSpeed3pm    Humidity9am  \
# count  119590.000000  119590.000000  119590.000000  119590.000000
# mean       40.107643      14.363818      19.082239      68.289782
# std        13.479752       8.796346       8.675334      19.129275
# min         6.000000       0.000000       0.000000       0.000000
# ...

# %% [markdown]
# Use info () to find the concise summary of the updated data frame.

# %%
# concise summary of updated DataFrame.

X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119590 entries, 0 to 119589
# Data columns (total 17 columns):
# index            119590 non-null int64
# Date             119590 non-null object
# MinTemp          119590 non-null float64
# MaxTemp          119590 non-null float64
# Rainfall         119590 non-null float64
# WindGustSpeed    119590 non-null float64
# WindSpeed9am     119590 non-null float64
# WindSpeed3pm     119590 non-null float64
# Humidity9am      119590 non-null float64
# Humidity3pm      119590 non-null float64
# Pressure9am      119590 non-null float64
# Pressure3pm      119590 non-null float64
# Temp9am          119590 non-null float64
# Temp3pm          119590 non-null float64
# year             119590 non-null int64
# month            119590 non-null int64
# day              119590 non-null int64
# dtypes: float64(12), int64(4), object(1)
# memory usage: 15.5+ MB

# %% [markdown]
# ## Visualization of the data

# %% [markdown]
# Once the preprocessing is done then we can visualize the data and plot graphs using matplotlib package. By Visualization, We can visualize the relation between any two or more variables.

# %% [markdown]
# Here in the first graph I am plotting a line graph to show the Max Temperature and the Minimum Temperature for a particular year say 2017.

# %%
#To Plot a line graph to see the variations in the MaxTemp and MinTemp on a particular year.

X_minmax= X[(X['year'] == 2017)]
print(X_minmax)
X_minmax= X_minmax.plot( y=['MaxTemp','MinTemp'],figsize=(20,10))
# Out:
#          index        Date  MinTemp  MaxTemp  Rainfall  WindGustSpeed  \
# 2806      2840  2017-01-01     15.5     31.6       0.0           39.0
# 2807      2841  2017-01-02     14.9     32.0       0.0           35.0
# 2808      2842  2017-01-03     13.7     32.0       0.0           24.0
# 2809      2843  2017-01-04     16.2     33.0       0.0           26.0
# 2810      2844  2017-01-05     18.0     33.5       0.0           35.0
# 2811      2845  2017-01-06     17.1     35.4       0.0           30.0
# 2812      2846  2017-01-07     17.9     35.4       0.0           28.0
# 2813      2847  2017-01-08     19.1     36.0       0.0           24.0
# 2814      2848  2017-01-09     21.3     30.7       0.0           33.0
# 2815      2849  2017-01-10     19.8     31.0      10.6           20.0
# 2816      2850  2017-01-11     20.1     34.2       0.0           39.0
# 2817      2851  2017-01-12     14.5     35.0       0.0           20.0
# ...

# %% [markdown]
# In the second graph I have visualized the Pressure at 9am and pressure at 3pm for every month.

# %%
#To plot a line graph to see the mean pressure variance at 9am and 3pm of different locations. 

X_p= X[['month','Pressure3pm','Pressure9am']].groupby(['month']).mean().reset_index()
print(X_p)
X_p.plot( y=['Pressure3pm','Pressure9am'],figsize=(20,10))
# Out:
#     month  Pressure3pm  Pressure9am
# 0       1  1010.546051  1012.730731
# 1       2  1012.332937  1014.475334
# 2       3  1014.544008  1016.752361
# 3       4  1017.066476  1019.676178
# 4       5  1017.986275  1020.493937
# 5       6  1018.879515  1021.205061
# 6       7  1018.709188  1021.108310
# 7       8  1017.039304  1019.646665
# 8       9  1015.283179  1018.100726
# 9      10  1015.905689  1018.370824
# 10     11  1013.097564  1015.456456
# 11     12  1011.112574  1013.336908

# %% [markdown]
# Finally I have decided to find the correlation between all the feature values and so plotted a correlation matrix using heatmap.

# %%
# To plot the correlation matrix which shows the correlation between any two variables.

f, ax = plt.subplots(figsize=(10,8))
corr = X.corr()
sns.heatmap(corr, fmt = ".2f",annot = True)

# %% [markdown]
# ## PRELIMINARY OBSERVATION

# %% [markdown]
# The visualization of data set gives you a clear picture of areas that need attention or improvement. It also clarifies which factors influence the behavior.
#
# From the first graph we can infer the variations between the max Temperature and the min Temperature in a particular year. Here I have selected the year'2017' and plotted a line graph where the blue line shows the variation of the max Temperature and the orange line shows the variation of the min Temperature.
#
# From the second graph we can infer the mean pressure for every month at 9am and 3pm. The blue line shows the pressure at 3pm and the yellow line shows the pressure at 9am.
#
# The third graph contains the correlation matrix which provides the correlation between each feature value. We can find the measurement line which shows how much related the two variables will be. Higher the value (red) higher the correlation and vice versa. For example, we can infer that Temperature at 3 am and Max Temperature has higher correlation value which shows they are more correlated.

# %% [markdown]
# ## Preprocessing after Visualization

# %% [markdown]
# Here we remove the columns which are not required for the prediction. Since the prediction is about the temperature at 3pm I am removing columns like Location, Date, day, month , year and index.

# %%
X1 = X.loc[:, ~X.columns.isin([ 'Location','Date','day', 'month', 'year', 'index'])]
X1
# Out:
#         MinTemp  MaxTemp  Rainfall  WindGustSpeed  WindSpeed9am  WindSpeed3pm  \
# 0          13.4     22.9       0.6           44.0          20.0          24.0
# 1           7.4     25.1       0.0           44.0           4.0          22.0
# 2          12.9     25.7       0.0           46.0          19.0          26.0
# 3           9.2     28.0       0.0           24.0          11.0           9.0
# 4          17.5     32.3       1.0           41.0           7.0          20.0
# 5          14.6     29.7       0.2           56.0          19.0          24.0
# 6          14.3     25.0       0.0           50.0          20.0          24.0
# 7           7.7     26.7       0.0           35.0           6.0          17.0
# 8           9.7     31.9       0.0           80.0           7.0          28.0
# 9          13.1     30.1       1.4           28.0          15.0          11.0
# 10         13.4     30.4       0.0           30.0          17.0           6.0
# ...

# %% [markdown]
# ## Normalize the data

# %%
def normalize(X):
    mu = X.mean() 
    std = X.std()
    return (X - mu) / std


nX = normalize(X1)

X2 = nX.iloc[:,nX.columns != 'Temp3pm']

T = nX.iloc[:, nX.columns == 'Temp3pm']

X2 = X2.values
T = T.values

# %% [markdown]
# ## Split the data into test and train data

# %%
# now partition the data 

""" partitioning data

    parameters
    -----------
    X        pd.DataFrame
             input data to partition
    T        pd.DataFrame
             target labels to partition
    raito    list
             list of ratios for partitions (should be summed to 1) 
             the number of return pairs are different
"""
def partition(X, T, ratio=[0.8, 0.2]): 
    
    assert(np.sum(ratio) == 1)
    
    # shuffle the data indices 
    idxs = np.random.permutation(X.index)
    
    # the number of samples 
    N = X.shape[0]
    
    Xs = []
    Ts = []
    i = 0  # first index to zero
    for k, r in enumerate(ratio):
        nrows = int(round(N * r))  # number of rows
        
        if k == len(ratio) -1:
            Xs.append(X.iloc[i:, :])
            Ts.append(T.iloc[i:, :])
        else:
            Xs.append(X.iloc[i:i+nrows, :])
            Ts.append(T.iloc[i:i+nrows, :])
        
        i += nrows
    
    return Xs, Ts

# %% [markdown]
# Call the partition function to split the data into test and train data

# %%
Xlst, Tlst = partition(pd.DataFrame(X2), pd.DataFrame(T))

X2_train, X2_test = [xx.as_matrix() for xx in Xlst]
T_train, T_test = [tt.as_matrix() for tt in Tlst]
# Out:
# C:\Users\Anju\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\Anju\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   after removing the cwd from sys.path.

# %% [markdown]
# ## METHOD

# %% [markdown]
# ## REVIEW
#
# LINEAR MODELS :
#
# 1. LEAST SQUARE:
#
# Least square statistical technique for finding the best-fitting curve to a given set of points by minimizing the sum of the squares of the offsets ("the residuals") of the points from the curve.
#
# This is used to calculate the weight vector W = (((X)^T)X^-1)(X^T)t
#
# where w is the weight vector
# x is the independent variable
# T is the transpose function
# t is the dependent variable.
#
# and the Y is predicted using euclidean products.
#
# All the products done are euclidean products.
#
# Least square is similar to the batch learning which generate the best predictor by learning on the entire training data set at once.
#
# 2. LEAST MEAN SQUARE:
#
# Least squares means that the overall solution minimizes the sum of the squares of the residuals made in the results of every single equation.
#
# This is used to calculate the weight vector w(k+1)=w(k)−α(w(k)⊤xk−tk)xk.
#
# where w is the weight vector
# T is the transpose function
# x is the independent variable.
#
# and the Y is predicted using euclidean products.
#
#
# All the products done are euclidean products.
#
# Least square is similar to the online learning where data becomes available in a sequential order and is used to update our best predictor for future data at each step

# %% [markdown]
# ## EXPLANATION OF CODES

# %% [markdown]
# ## LINEAR MODELS
#
# Here we have described about two Linear Regression Models.
#
# 1. Least Square
# 2. Least Mean Square
#
# X2 -> Independent variable
# T -> Dependent variable.
#
# Now we have the data frame split into four arrays.
#
# 1.	X2_train
# 2.	T_train
#
# Where these two contains the data used for training and
#
# 3.	X2_test
# 4.	T_test
#
# These two arrays are used to test the trained model.
#
#
# ## BaseModel Class:
# The Base model class is the super class which has two abstract methods train and use.
#
#
# ## LinearModel Class:
# This class LinearModel is an abstract class which contains the init function, _check_matrix and add_ones.
#
# In the init function the weight vector w is initialized to None.
#
# ### _check_matrix(self, mat, name):
#
#  This function is used to check if the matrix is 2 dimensional or not. To plot a graph it has to be in two-dimensional. So inorder to verify if it is of two dimensional we have used the method_check_matrix.
# It has two parameters mat and name
# Where mat denotes the matrix and the name denotes the name of the matrix.
#
# ### add_ones(self, X):
#
# This function is used to add a column of ones only if the matrix is two-dimensional. So it calls the self function _check_matrix to check if it is a two-dimensional matrix or not.
#
# If yes then it adds a column of ones with the number of rows equal to the number of rows in the input matrix X.
#
# Here np.hstack is used to stack array in sequence horizontally (column-wise).
# This is equivalent to concatenation along the second axis, except for 1-D arrays where it concatenates along the first axis.
#
# ## Least Square Class:
#
# A mathematical procedure for finding the best-fitting curve to a given set of points by minimizing the sum of the square of the offsets("the residuals") of the points from the curve. The sum of the squares of the offsets is used instead of the offset absolute values because this allows the residuals to be treated as a continuous differentiable quantity.
#
# The Class Linear Regress has two methods
#
# ### train(self, X, T):
# This function is used to calculate the weight vector.
#
# w = (((X)^TX)^-1)X^T *t
#
# where w is the weight vector,
# X is the independent variable
# T is the transpose function
# t is the dependant variable.
#
#
# This method calls the add_ones function that is described in Linear model and add ones to the matrix if it is a two-dimensional matrix.
# Here numpy.linalg.lstsq is used which returns the least-squares solution to a linear matrix equation.
# It has two parameters X and T which are the arrays where X is the independent variable and T is the dependent variable.
#
#
# ### use(self, X):
#
# This method is used to apply the learned model in data X and predicts the value.
#
# This method calls the add_ones function that is described in Linear model and add ones to the matrix if it is a two-dimensional matrix.
#
# This predicts the values of dependent variable in the test data.
#
#
# ## LMS:
#
# Least mean square method is used when there is a large data set and the data keeps adding continuously. Here weights is calculated for each row seperately and weight gets updated at each step.
#
#
# So here apart from the two methods train and use we have used one more method train_step.
#
# ### train(self, X, T):
#
# This function definition contains the calling function of train_step method. So for each sample th train_step is called.
#
# ### train_step(self, x, t):
#
# In this function verifies the below two cases
#
# 1. if it is not a two dimentional array it adds one for consistency and reshapes the one dimensional into two dimensional matrix.
#
# 2. If the weight vector is None it adds a column of zeros.
#
# and once these two conditions are checked then it calculates the weight using the below formula.
#
# w(k+1)=w(k)−α((w(k)^⊤)x(k)−t(k))x(k).
#
#
#
# ### use(self, X):
#
# This method is used to apply the learned model in data X and predicts the value.
#
# This method calls the add_ones function that is described in Linear model and add ones to the matrix if it is a two-dimensional matrix.
#
# This predicts the values of dependent variable in the test data using Eucledian dot product.
#
# t = (w^T)@(X)^T
#
# where @ is the Euclidean dot product.
# T is the transpose function
#
# t is the predicted value.
#
#
#
# In all the calculations -
#
# @ - defines the euclidean dot product.

# %% [markdown]
# ## Super Classs Definition

# %%
# Super class for machine learning models 

class BaseModel(ABC):
    """ Super class for ITCS Machine Learning Class"""
    
    @abstractmethod
    def train(self, X, T):
        pass

    @abstractmethod
    def use(self, X):
        pass

    
class LinearModel(BaseModel):
    """
        Abstract class for a linear model 
        
        Attributes
        ==========
        w       ndarray
                weight vector/matrix
    """

    def __init__(self):
        """
            weight vector w is initialized as None
        """
        self.w = None

    # check if the matrix is 2-dimensional. if not, raise an exception    
    def _check_matrix(self, mat, name):
        if len(mat.shape) != 2:
            raise ValueError(''.join(["Wrong matrix ", name]))
        
    # add a basis
    def add_ones(self, X):
        """
            add a column basis to X input matrix
        """
        self._check_matrix(X, 'X')
        return np.hstack((np.ones((X.shape[0], 1)), X))

    ####################################################
    #### abstract funcitons ############################
    @abstractmethod
    def train(self, X, T):
        """
            train linear model
            
            parameters
            -----------
            X     2d array
                  input data
            T     2d array
                  target labels
        """        
        pass
    
    @abstractmethod
    def use(self, X):
        """
            apply the learned model to input X
            
            parameters
            ----------
            X     2d array
                  input data
            
        """        
        pass

# %% [markdown]
# ## Least Squares

# %%
# Linear Regression Class for least squares
class LinearRegress(LinearModel): 
    """ 
        LinearRegress class 
        
        attributes
        ===========
        w    nd.array  (column vector/matrix)
             weights
    """
    def __init__(self):
        LinearModel.__init__(self)
        
    # train lease-squares model
    def train(self, X, T):
        # calls the add_ones function defined in the LinearModel class and is stored in Y array.
        Y = self.add_ones(X) 
        # the weight vector for the whole data set is calculated. 
        # Euclidean dot product is calculated and numpy.linalg.lstsq returns the least-squares solution to a linear matrix equation.
        self.w = np.linalg.lstsq(Y.T @ Y, Y.T @ T)[0]
        

    # apply the learned model to data X
    def use(self, X):
        # calls the add_ones function defined in the LinearModel class and is stored in Y array.
        Y = self.add_ones(X)
        # Euclidean dot product is done with Y and and the w vector
        # Y1 is the predicted value for the dependant variable in the train set. 
        Y1 = Y @ self.w
        # return the predicted value.
        return Y1

# %% [markdown]
# ## Least Mean Square

# %%
import collections # for checking iterable instance

# LMS class 
class LMS(LinearModel):
    """
        Lease Mean Squares. online learning algorithm
    
        attributes
        ==========
        w        nd.array
                 weight matrix
        alpha    float
                 learning rate
    """
    def __init__(self, alpha):
        LinearModel.__init__(self)
        self.alpha = alpha
    
    # batch training by using train_step function
    def train(self, X, T):
        # N contains the number of rows in X
        N = X.shape[0]
        # loop statement to call the self.train_step function for each record.
        for i in range(N):
            self.train_step(X[i],T[i])
    
    # train LMS model one step 
    # here the x is 1d vector
    def train_step(self, x, t):
        # check if the matrix is of 2 dimentional else it reshapes the one dimentional.
        if len(x.shape)!=2:
            x = np.insert(x,0,1).reshape(-1,1)
        # Verifies if the weight vector is None else inserts a column of 1.
        if self.w is None:
            self.w = np.zeros((x.shape[0],1))
        # calculates the euclidean dot product of ((w(k)^⊤)x(k)−t(k)) where T is the Transpose.
        y = self.w.T@ x- t
        # calculates the  w(k)-(alpha((w(k)^⊤)x(k)−t(k)))*t.
        self.w = np.subtract(self.w, self.alpha * y * x)
        
    # apply the current model to data X
    def use(self, X):
        # predicts the value using euclidean dot product.
        t = self.w.T @ self.add_ones(X).T
        #returns the predicted value.
        return t.T

# %% [markdown]
# ## EXPERIMENTS

# %% [markdown]
# ### DESCRIPTION, CODES

# %% [markdown]
# #### Training the model in Least Square method (MULTIVARIATE)
#
# All the feature values are included (MinTemp, MaxTemp,Rainfall, WindGustSpeed, WindSpeed9am, WindSpeed3pm, Humidity9am, Humidity3pm, Pressure9am, Pressure3pm, Temp9am,	Temp3pm) in the dependent variable.

# %%
# Creating an object reg for the class LinearRegress
reg = LinearRegress()
# Calling the train method in LinearRegress class by passing the X2_train and T_train as parameters
reg.train(X2_train,T_train)

# %% [markdown]
# ### VISUALIZATION OF RESULTS
# #### Plotting the graph for the predicted data and test data.
#
# Residual plot is plotted between the predicted data and the test data.

# %%
#Plot the graph for the predicted data and the testdata.
plt.subplots(figsize = (20,8))
plt.plot(T_test)
plt.plot(reg.use(X2_test))

# %% [markdown]
# A scatter plot is plotted which shows the least square linear regression.

# %%
# Scatter plot is plotted for the predicted values.
plt.scatter(T_test, reg.use(X2_test))

# %% [markdown]
# ### DESCRIPTION, CODES

# %% [markdown]
# Training the model in Least Mean Square method (MULTIVARIATE):
#
# All the feature values are included (MinTemp, MaxTemp,Rainfall, WindGustSpeed, WindSpeed9am, WindSpeed3pm, Humidity9am, Humidity3pm, Pressure9am, Pressure3pm, Temp9am, Temp3pm) in the dependent variable.
#
# The alpha value is passed as a parameter while creating an object for the class LMS.

# %%
# object is created for LMS class and aplha value is passed as the parameter.
reg1 = LMS(0.0001)
# calling the train method by passing the X2_train and T_train as parameters.
reg1.train(X2_train,T_train)

# %% [markdown]
# ### VISUALIZATION OF CODES

# %% [markdown]
# #### Plotting the graph for the predicted data and test data.
#
# Residual plot is plotted between the predicted data and the test data.

# %%
# Plotting the graph for predicted data and test data.
plt.subplots(figsize = (20,8))
plt.plot(T_test)
plt.plot(reg1.use(X2_test))

# %% [markdown]
# ## ANALYSIS OR COMPARISON OF ALGORITHMS
#
# LEAST SQUARE:
#
# - It calculates the weights after calculating it for the entire data set.
# - It is similar to batch learning which generate the best predictor by learning on the entire training data set at once.
# - It is a better model if the data set is smaller.
#
# LEAST MEAN SQUARE:
# - It calculates the weight for each record and the weights are updated.
# - Least square is similar to the online learning where data becomes available in a sequential order and is used to update our best predictor for future data at each step
# - It is better when the data is huge and if the data is to be continously provided.

# %% [markdown]
# ## Correct Implementation of Preliminary Test

# %%
##################### WHAT I WILL RELEASE ############

# Self-Test code for accuracy of your model - DO NOT MODIFY THIS
# Primilnary test data
X = np.array([[2,5],
              [6,2],
              [1,9],
              [4,5],
              [6,3],
              [7,4],
              [8,3]])
T = X[:,0, None] * 3 - 2 * X[:, 1, None] + 3
N = X.shape[0]

def rmse(T, Y):
    return np.sqrt(np.sum((T-Y)**2))

model_names = ['LS', 'LMS_All', 'LMS_1STEP']
models = [LinearRegress(), LMS(0.02), LMS(0.02)]
#train
for i, model in enumerate(models):
    print("training ", model_names[i], "...") 
    if i == len(models) -1: 
        # train only one step for LMS2
        model.train_step(X[0], T[0])
    else:
        model.train(X, T)

def check(a, b, eps=np.finfo(float).eps):
    if abs(a-b) > eps:
        print("failed.", a, b)
    else:
        print("passed.")

errors = [1.19e-13, 2.8753214702, 38.0584918251]
for i, model in enumerate(models):
    print("---- Testing ", model_names[i], "...", end=" ") 
    
    # rmse test
    err = rmse(T, model.use(X))
    if check(err, errors[i], eps=1e-10):
        print ("check your weights: ", model.w)
        print ("oracle: ", )
# Out:
# training  LS ...
# training  LMS_All ...
# training  LMS_1STEP ...
# ---- Testing  LS ... passed.
# ---- Testing  LMS_All ... passed.
# ---- Testing  LMS_1STEP ... passed.

# %% [markdown]
# ## EXTRA CREDIT:
#
# As we can see we can remove the least significant and most significant value and plot a reduced plot.
#
# Here the temp3pm the least significant is Humidity at 3pm and most significant is maxTemp.

# %%
# removing the least significant feature value.(Humidity3pm)
X2 = nX.loc[:, ~nX.columns.isin([ 'Temp3pm', 'Humidity3pm'])]

T = nX.iloc[:, nX.columns == 'Temp3pm']

X2 = X2.values
T = T.values

reg.train(X2_train,T_train)

#Plot the graph for the predicted data and the testdata.
plt.subplots(figsize = (20,8))
plt.plot(T_test)
plt.plot(reg.use(X2_test))

# %% [markdown]
# ### Removing the most significant MaxTemp

# %%
# removing the most significant feature value
X2 = nX.loc[:, ~nX.columns.isin([ 'Temp3pm', 'MaxTemp'])]

T = nX.iloc[:, nX.columns == 'Temp3pm']

X2 = X2.values
T = T.values

reg1.train(X2_train,T_train)

#Plot the graph for the predicted data and the testdata.
plt.subplots(figsize = (20,8))
plt.plot(T_test)
plt.plot(reg1.use(X2_test))

# %% [markdown]
# ## CONCLUSION:
#
# This assignment gave me a clear view about the linear regression concept. It also helped me to predict the data if it is a univariate, bivariate or multivariate.
#
# It also taught me the concepts of Linear Square and Linear Mean Square method.
#
# This was a great hands on assignment to work with the Linear Regression models.
#
# Over all I got to learn how to predict the data and visualize them.

# %% [markdown]
# ## REFRENCES:
#
# [1] The Jupyter Notebook provided by professor Lee  https://nbviewer.jupyter.org/url/webpages.uncc.edu/mlee173/teach/itcs6156/notebooks/wb/ForestFire.ipynb
#
# [2] SciPy Learn, numpy.linalg.lstsq,  "https://docs.scipy.org/doc/numpy-1.13.0/reference/generated/numpy.linalg.lstsq.html"
#
# [3] Pandas 0.24.0 documentation » API Reference » DataFrame » pandas.DataFrame » pandas.DataFrame.plot. General Writing FAQs.Retrieved from "https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.plot.html".
#
# [4] Pandas 0.24.0 documentation » API Reference » DataFrame » pandas.iloc » pandas.DataFrame.iloc. General Writing FAQs.Retrieved from "https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.iloc.html".
#
# [5] SciPy Learn, numpy.ndarray.shape, "https://docs.scipy.org/doc/numpy-1.14.5/reference/generated/numpy.ndarray.shape.html"
